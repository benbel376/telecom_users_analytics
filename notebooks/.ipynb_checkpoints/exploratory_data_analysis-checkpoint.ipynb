# %% [markdown]
# <h1> TeleCo Customers Data Exploration</h1>

# %% [markdown]
# <h2> Imporing data and packages </h2>

# %% [markdown]
# Importing essential libraries

# %%
import pandas as pd
import numpy as np
import os
import warnings
from pandasql import sqldf
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %% [markdown]
# Suppressing warning messages

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Setting file paths

# %%
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir)) # setting path to parent directory
scripts_dir = os.path.join(parent_dir,"scripts") # setting path to scripts directory
data_path = os.path.join(parent_dir,"data","teleco_customers_data.csv") # setting path to data directory

sys.path.insert(1, scripts_dir)

# %% [markdown]
# Importing data cleaning and summarizing scripts

# %%
from data_cleaning_functions import DataCleaner as Cleaner 
from data_summarizing_functions import DataSummarizer as Sumar

cleaner = Cleaner()
sumar = Sumar()

# %% [markdown]
# Loading the data

# %%
df = pd.read_csv(data_path)

# %% [markdown]
# <h2>Data Cleaning</h2>

# %% [markdown]
# Taking a first look at the data

# %%
df.head() # looking the first few rows of the data.
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
df.shape # checking number of columns and rows
# Out:
# (150001, 55)

# %%
sumar.percent_missing(df) # looking at the percentage of total missing values in the data set
# Out:
# The dataset contains 12.5 % missing values.

# %%
sumar.summ_columns(df) # looking at all available columns
# Out:
#                                    variables  missing_count  \
# 0                                  Bearer Id            991
# 1                                      Start              1
# 2                                   Start ms              1
# 3                                        End              1
# 4                                     End ms              1
# 5                                  Dur. (ms)              1
# 6                                       IMSI            570
# 7                              MSISDN/Number           1066
# 8                                       IMEI            572
# 9                         Last Location Name           1153
# 10                           Avg RTT DL (ms)          27829
# 11                           Avg RTT UL (ms)          27812
# 12                   Avg Bearer TP DL (kbps)              1
# 13                   Avg Bearer TP UL (kbps)              1
# 14               TCP DL Retrans. Vol (Bytes)          88146
# 15               TCP UL Retrans. Vol (Bytes)          96649
# 16                       DL TP < 50 Kbps (%)            754
# 17            50 Kbps < DL TP < 250 Kbps (%)            754
# 18             250 Kbps < DL TP < 1 Mbps (%)            754
# 19                        DL TP > 1 Mbps (%)            754
# 20                       UL TP < 10 Kbps (%)            792
# 21             10 Kbps < UL TP < 50 Kbps (%)            792
# 22            50 Kbps < UL TP < 300 Kbps (%)            792
# 23                      UL TP > 300 Kbps (%)            792
# 24                           HTTP DL (Bytes)          81474
# 25                           HTTP UL (Bytes)          81810
# 26                 Activity Duration DL (ms)              1
# 27                 Activity Duration UL (ms)              1
# 28                               Dur. (ms).1              1
# 29                      Handset Manufacturer            572
# 30                              Handset Type            572
# 31           Nb of sec with 125000B < Vol DL          97538
# 32     Nb of sec with 1250B < Vol UL < 6250B          92894
# 33  Nb of sec with 31250B < Vol DL < 125000B          93586
# 34            Nb of sec with 37500B < Vol UL         130254
# 35    Nb of sec with 6250B < Vol DL < 31250B          88317
# 36    Nb of sec with 6250B < Vol UL < 37500B         111843
# 37             Nb of sec with Vol DL < 6250B            755
# 38             Nb of sec with Vol UL < 1250B            793
# 39                   Social Media DL (Bytes)              0
# 40                   Social Media UL (Bytes)              0
# 41                         Google DL (Bytes)              0
# 42                         Google UL (Bytes)              0
# 43                          Email DL (Bytes)              0
# 44                          Email UL (Bytes)              0
# 45                        Youtube DL (Bytes)              0
# 46                        Youtube UL (Bytes)              0
# 47                        Netflix DL (Bytes)              0
# 48                        Netflix UL (Bytes)              0
# 49                         Gaming DL (Bytes)              0
# 50                         Gaming UL (Bytes)              0
# 51                          Other DL (Bytes)              0
# 52                          Other UL (Bytes)              0
# 53                          Total UL (Bytes)              1
# 54                          Total DL (Bytes)              1
#
#     missing_percent_(%) data_type  unique_values
# 0                   1.0   float64         134709
# 1                   0.0    object           9998
# 2                   0.0   float64           1001
# 3                   0.0    object           6404
# 4                   0.0   float64           1001
# 5                   0.0   float64          89526
# 6                   0.0   float64         107266
# 7                   1.0   float64         106857
# 8                   0.0   float64         107271
# 9                   1.0    object          45548
# 10                 19.0   float64           2131
# 11                 19.0   float64            723
# 12                  0.0   float64          41754
# 13                  0.0   float64          14529
# 14                 59.0   float64          54400
# 15                 64.0   float64          35121
# 16                  1.0   float64            101
# 17                  1.0   float64             85
# 18                  1.0   float64             74
# 19                  1.0   float64             86
# 20                  1.0   float64             99
# 21                  1.0   float64             86
# 22                  1.0   float64             69
# 23                  1.0   float64             64
# 24                 54.0   float64          63528
# 25                 55.0   float64          59943
# 26                  0.0   float64         102561
# 27                  0.0   float64         106293
# 28                  0.0   float64         122872
# 29                  0.0    object            171
# 30                  0.0    object           1397
# 31                 65.0   float64           6459
# 32                 62.0   float64           3399
# 33                 62.0   float64           5756
# 34                 87.0   float64           1105
# 35                 59.0   float64           6173
# 36                 75.0   float64           1711
# 37                  1.0   float64          22271
# 38                  1.0   float64          22977
# 39                  0.0   float64         146856
# 40                  0.0   float64          59078
# 41                  0.0   float64         149024
# 42                  0.0   float64         147267
# 43                  0.0   float64         146916
# 44                  0.0   float64         138699
# 45                  0.0   float64         149547
# 46                  0.0   float64         149477
# 47                  0.0   float64         149518
# 48                  0.0   float64         149490
# 49                  0.0   float64         149983
# 50                  0.0   float64         149316
# 51                  0.0   float64         149986
# 52                  0.0   float64         149284
# 53                  0.0   float64         149729
# 54                  0.0   float64         149988

# %% [markdown]
# **Observation**
# <ul>
#     <li> there are 150,0001 rows and 55 columns of data.</li>
#     <li> some rows are missing upto 87% of their data.</li>
#     <li> The columns are of two data types: string and float</li>
#
# </ul>

# %% [markdown]
# Dimensionality reduction based on missing values. columns with greater than 30% data loss will be removed

# %%
df2 = cleaner.reduce_dim_missing(df, 30)
df2.shape
# Out:
# (150001, 45)

# %%
keep_list = ['Bearer Id','Dur. (ms)','IMSI','MSISDN/Number','IMEI','Activity Duration DL (ms)','Activity Duration UL (ms)','Handset Manufacturer','Handset Type','Social Media DL (Bytes)','Social Media UL (Bytes)','Google DL (Bytes)','Google UL (Bytes)','Email DL (Bytes)','Email UL (Bytes)','Youtube DL (Bytes)','Youtube UL (Bytes)','Netflix DL (Bytes)','Netflix UL (Bytes)','Gaming DL (Bytes)','Gaming UL (Bytes)','Other DL (Bytes)','Other UL (Bytes)','Total UL (Bytes)','Total DL (Bytes)']

df3 = cleaner.remove_cols(df2, keep_list, True)
sumar.summ_columns(df3)
# Out:
#                     variables  missing_count  missing_percent_(%) data_type  \
# 0                   Bearer Id            991                  1.0   float64
# 1                   Dur. (ms)              1                  0.0   float64
# 2                        IMSI            570                  0.0   float64
# 3               MSISDN/Number           1066                  1.0   float64
# 4                        IMEI            572                  0.0   float64
# 5   Activity Duration DL (ms)              1                  0.0   float64
# 6   Activity Duration UL (ms)              1                  0.0   float64
# 7        Handset Manufacturer            572                  0.0    object
# 8                Handset Type            572                  0.0    object
# 9     Social Media DL (Bytes)              0                  0.0   float64
# 10    Social Media UL (Bytes)              0                  0.0   float64
# 11          Google DL (Bytes)              0                  0.0   float64
# 12          Google UL (Bytes)              0                  0.0   float64
# 13           Email DL (Bytes)              0                  0.0   float64
# 14           Email UL (Bytes)              0                  0.0   float64
# 15         Youtube DL (Bytes)              0                  0.0   float64
# 16         Youtube UL (Bytes)              0                  0.0   float64
# 17         Netflix DL (Bytes)              0                  0.0   float64
# 18         Netflix UL (Bytes)              0                  0.0   float64
# 19          Gaming DL (Bytes)              0                  0.0   float64
# 20          Gaming UL (Bytes)              0                  0.0   float64
# 21           Other DL (Bytes)              0                  0.0   float64
# 22           Other UL (Bytes)              0                  0.0   float64
# 23           Total UL (Bytes)              1                  0.0   float64
# 24           Total DL (Bytes)              1                  0.0   float64
#
#     unique_values
# 0          134709
# 1           89526
# 2          107266
# 3          106857
# 4          107271
# 5          102561
# 6          106293
# 7             171
# 8            1397
# 9          146856
# 10          59078
# 11         149024
# 12         147267
# 13         146916
# 14         138699
# 15         149547
# 16         149477
# 17         149518
# 18         149490
# 19         149983
# 20         149316
# 21         149986
# 22         149284
# 23         149729
# 24         149988

# %% [markdown]
# Adjusting the data type of id columns

# %%
df3 = cleaner.format_number(df3, ['Bearer Id','IMSI','MSISDN/Number','IMEI']) # this will convert the specified columns to object type
sumar.summ_columns(df3)
# Out:
#                     variables  missing_count  missing_percent_(%) data_type  \
# 0                   Bearer Id              0                  0.0    object
# 1                   Dur. (ms)              1                  0.0   float64
# 2                        IMSI              0                  0.0    object
# 3               MSISDN/Number              0                  0.0    object
# 4                        IMEI              0                  0.0    object
# 5   Activity Duration DL (ms)              1                  0.0   float64
# 6   Activity Duration UL (ms)              1                  0.0   float64
# 7        Handset Manufacturer            572                  0.0    object
# 8                Handset Type            572                  0.0    object
# 9     Social Media DL (Bytes)              0                  0.0   float64
# 10    Social Media UL (Bytes)              0                  0.0   float64
# 11          Google DL (Bytes)              0                  0.0   float64
# 12          Google UL (Bytes)              0                  0.0   float64
# 13           Email DL (Bytes)              0                  0.0   float64
# 14           Email UL (Bytes)              0                  0.0   float64
# 15         Youtube DL (Bytes)              0                  0.0   float64
# 16         Youtube UL (Bytes)              0                  0.0   float64
# 17         Netflix DL (Bytes)              0                  0.0   float64
# 18         Netflix UL (Bytes)              0                  0.0   float64
# 19          Gaming DL (Bytes)              0                  0.0   float64
# 20          Gaming UL (Bytes)              0                  0.0   float64
# 21           Other DL (Bytes)              0                  0.0   float64
# 22           Other UL (Bytes)              0                  0.0   float64
# 23           Total UL (Bytes)              1                  0.0   float64
# 24           Total DL (Bytes)              1                  0.0   float64
#
#     unique_values
# 0          134709
# 1           89526
# 2          107266
# 3          106857
# 4          107271
# 5          102561
# 6          106293
# 7             171
# 8            1397
# 9          146856
# 10          59078
# 11         149024
# 12         147267
# 13         146916
# 14         138699
# 15         149547
# 16         149477
# 17         149518
# 18         149490
# 19         149983
# 20         149316
# 21         149986
# 22         149284
# 23         149729
# 24         149988

# %% [markdown]
# missing values of categorical variables will be filled by mode
# and missing values of  numerical variables will be filled by median values

# %%
df3 = cleaner.fill_missing_by_mode(df3) # fills all categorical variables with mode
df3 = cleaner.fill_missing_by_median(df3) # fills all numerical variables with median
sumar.summ_columns(df3)
# Out:
#                     variables  missing_count  missing_percent_(%) data_type  \
# 0                   Bearer Id              0                  0.0    object
# 1                   Dur. (ms)              0                  0.0   float64
# 2                        IMSI              0                  0.0    object
# 3               MSISDN/Number              0                  0.0    object
# 4                        IMEI              0                  0.0    object
# 5   Activity Duration DL (ms)              0                  0.0   float64
# 6   Activity Duration UL (ms)              0                  0.0   float64
# 7        Handset Manufacturer              0                  0.0    object
# 8                Handset Type              0                  0.0    object
# 9     Social Media DL (Bytes)              0                  0.0   float64
# 10    Social Media UL (Bytes)              0                  0.0   float64
# 11          Google DL (Bytes)              0                  0.0   float64
# 12          Google UL (Bytes)              0                  0.0   float64
# 13           Email DL (Bytes)              0                  0.0   float64
# 14           Email UL (Bytes)              0                  0.0   float64
# 15         Youtube DL (Bytes)              0                  0.0   float64
# 16         Youtube UL (Bytes)              0                  0.0   float64
# 17         Netflix DL (Bytes)              0                  0.0   float64
# 18         Netflix UL (Bytes)              0                  0.0   float64
# 19          Gaming DL (Bytes)              0                  0.0   float64
# 20          Gaming UL (Bytes)              0                  0.0   float64
# 21           Other DL (Bytes)              0                  0.0   float64
# 22           Other UL (Bytes)              0                  0.0   float64
# 23           Total UL (Bytes)              0                  0.0   float64
# 24           Total DL (Bytes)              0                  0.0   float64
#
#     unique_values
# 0          134709
# 1           89525
# 2          107266
# 3          106857
# 4          107271
# 5          102561
# 6          106293
# 7             170
# 8            1396
# 9          146856
# 10          59078
# 11         149024
# 12         147267
# 13         146916
# 14         138699
# 15         149547
# 16         149477
# 17         149518
# 18         149490
# 19         149983
# 20         149316
# 21         149986
# 22         149284
# 23         149729
# 24         149988

# %% [markdown]
# Converting Bytes to Megabytes.

# %%
df3 = cleaner.byte_to_mb(df3, "(Bytes)")
sumar.summ_columns(df3)
# Out:
#                     variables  missing_count  missing_percent_(%) data_type  \
# 0                   Bearer Id              0                  0.0    object
# 1                   Dur. (ms)              0                  0.0   float64
# 2                        IMSI              0                  0.0    object
# 3               MSISDN/Number              0                  0.0    object
# 4                        IMEI              0                  0.0    object
# 5   Activity Duration DL (ms)              0                  0.0   float64
# 6   Activity Duration UL (ms)              0                  0.0   float64
# 7        Handset Manufacturer              0                  0.0    object
# 8                Handset Type              0                  0.0    object
# 9        Social Media DL (MB)              0                  0.0   float64
# 10       Social Media UL (MB)              0                  0.0   float64
# 11             Google DL (MB)              0                  0.0   float64
# 12             Google UL (MB)              0                  0.0   float64
# 13              Email DL (MB)              0                  0.0   float64
# 14              Email UL (MB)              0                  0.0   float64
# 15            Youtube DL (MB)              0                  0.0   float64
# 16            Youtube UL (MB)              0                  0.0   float64
# 17            Netflix DL (MB)              0                  0.0   float64
# 18            Netflix UL (MB)              0                  0.0   float64
# 19             Gaming DL (MB)              0                  0.0   float64
# 20             Gaming UL (MB)              0                  0.0   float64
# 21              Other DL (MB)              0                  0.0   float64
# 22              Other UL (MB)              0                  0.0   float64
# 23              Total UL (MB)              0                  0.0   float64
# 24              Total DL (MB)              0                  0.0   float64
#
#     unique_values
# 0          134709
# 1           89525
# 2          107266
# 3          106857
# 4          107271
# 5          102561
# 6          106293
# 7             170
# 8            1396
# 9          146856
# 10          59078
# 11         149024
# 12         147267
# 13         146916
# 14         138699
# 15         149547
# 16         149477
# 17         149518
# 18         149490
# 19         149983
# 20         149316
# 21         149986
# 22         149284
# 23         149729
# 24         149988

# %% [markdown]
# <h2>Univariate Analysis</h2>

# %% [markdown]
# **SQL query based functions to explore handsets and their manufacturers**

# %% [markdown]
# What are the top 10 handsets used by customers?

# %%
handsets_df = sumar.get_top_n("df3", "Handset Type", 10, globals())
handsets_df
# Out:
#                    Handset Type  user_count
# 0              Huawei B528S-23A       20324
# 1       Apple iPhone 6S (A1688)        9419
# 2        Apple iPhone 6 (A1586)        9023
# 3        Apple iPhone 7 (A1778)        6326
# 4       Apple iPhone Se (A1723)        5187
# 5        Apple iPhone 8 (A1905)        4993
# 6       Apple iPhone Xr (A2105)        4568
# 7  Samsung Galaxy S8 (Sm-G950F)        4520
# 8        Apple iPhone X (A1901)        3813
# 9    Samsung Galaxy A5 Sm-A520F        3724

# %% [markdown]
# What are the top 3 handset manufacturers?

# %%
sumar.plot_pie(handsets_df, ['Handset Type','user_count'], "The top 10 handset used by customers")

# %%
top_man = sumar.get_top_n("df3", "Handset Manufacturer", 3, globals())
top_man
# Out:
#   Handset Manufacturer  user_count
# 0                Apple       60137
# 1              Samsung       40839
# 2               Huawei       34423

# %%
sumar.plot_pie(top_man, ['Handset Manufacturer','user_count'], "The top 3 handset manufacturers")

# %% [markdown]
# What are the top 5 Handsets per the top 3 handset manufacturers

# %%
sumar.manByHandset(top_man["Handset Manufacturer"].to_list(),'df3', globals())
# Out:
#   Handset Manufacturer             Handset Type  num_users
# 0                Apple  Apple iPhone 6S (A1688)       9419
# 1                Apple   Apple iPhone 6 (A1586)       9023
# 2                Apple   Apple iPhone 7 (A1778)       6326
# 3                Apple  Apple iPhone Se (A1723)       5187
# 4                Apple   Apple iPhone 8 (A1905)       4993
#
#   Handset Manufacturer                  Handset Type  num_users
# 0              Samsung  Samsung Galaxy S8 (Sm-G950F)       4520
# 1              Samsung    Samsung Galaxy A5 Sm-A520F       3724
# 2              Samsung   Samsung Galaxy J5 (Sm-J530)       3696
# 3              Samsung   Samsung Galaxy J3 (Sm-J330)       3484
# 4              Samsung  Samsung Galaxy S7 (Sm-G930X)       3199
#
#   Handset Manufacturer                    Handset Type  num_users
# 0               Huawei                Huawei B528S-23A      19752
# 1               Huawei                    Huawei E5180       2079
# 2               Huawei  Huawei P20 Lite Huawei Nova 3E       2021
# 3               Huawei                      Huawei P20       1480
# 4               Huawei                  Huawei Y6 2018        997

# %% [markdown]
# **Observation**
# <ul>
# <li> The most used handset type is Huawei B528S-23A </li>
# <li> But most of the handsets used are manufactured by Apple </li>
# <li> From among the top three manufacturers, Apple iPhone 6S, Samsung Galaxy S8 (Sm-G950F), and Huawei B528S-23A are
# the most used handsets</li>
#
# </ul>

# %% [markdown]
# <h3> Aggregating the data for further exploration </h3>

# %%
grouping_lis = ["MSISDN/Number"]
aggr_lis = ["Bearer Id", "Dur. (ms)", "Total DL (MB)", "Total UL (MB)", "Social Media DL (MB)", "Social Media UL (MB)",\
    "Youtube DL (MB)", "Youtube UL (MB)", "Netflix DL (MB)", "Netflix UL (MB)", "Google DL (MB)", "Google UL (MB)","Gaming DL (MB)","Gaming UL (MB)", "Email DL (MB)", "Email UL (MB)", "Other DL (MB)", "Other UL (MB)"] 
metric_lis = ["count", "sum", "sum", "sum", "sum", "sum", "sum", "sum","sum", "sum", "sum", "sum", "sum", "sum", "sum","sum", "sum","sum"]
col_names = ["xDr_session_count", "session_dur", "Total_DL", "Total_UL", "Social_DL", "Social_UL",\
    "Youtube_DL", "Youtube_UL", "Netflix_DL", "Netflix_UL", "Google_DL", "Google_UL", "Gaming_DL", "Gaming_UL", "Email_DL", "Email_UL", "Other_DL", "Other_UL"]


aggr_df = sumar.find_agg(df3, grouping_lis, aggr_lis, metric_lis, col_names)
sumar.combineColumns(aggr_df, "Total_DL", "Total_UL", "total_vol")
sumar.combineColumns(aggr_df, "Youtube_DL", "Youtube_UL", "youtube", True)
sumar.combineColumns(aggr_df, "Netflix_DL", "Netflix_UL", "netflix", True)
sumar.combineColumns(aggr_df, "Google_DL", "Google_UL", "google", True)
sumar.combineColumns(aggr_df, "Gaming_DL", "Gaming_UL", "gaming", True)
sumar.combineColumns(aggr_df, "Email_DL", "Email_UL", "email", True)
sumar.combineColumns(aggr_df, "Social_DL", "Social_UL", "social", True)
sumar.combineColumns(aggr_df, "Other_DL", "Other_UL", "other", True)

# %%
sumar.summ_columns(aggr_df)
# Out:
#             variables  missing_count  missing_percent_(%) data_type  \
# 0       MSISDN/Number              0                  0.0    object
# 1   xDr_session_count              0                  0.0     int64
# 2         session_dur              0                  0.0   float64
# 3            Total_DL              0                  0.0   float64
# 4            Total_UL              0                  0.0   float64
# 5           total_vol              0                  0.0   float64
# 6             youtube              0                  0.0   float64
# 7             netflix              0                  0.0   float64
# 8              google              0                  0.0   float64
# 9              gaming              0                  0.0   float64
# 10              email              0                  0.0   float64
# 11             social              0                  0.0   float64
# 12              other              0                  0.0   float64
#
#     unique_values
# 0          106857
# 1              18
# 2           77539
# 3          106853
# 4          106782
# 5          106854
# 6          106763
# 7          106765
# 8          106637
# 9          106855
# 10         106139
# 11         106138
# 12         106853

# %%
#sample_data = aggr_df.sample(3000)
sumar.plot_box(aggr_df, ['youtube', 'netflix', 'google', 'gaming', 'email', 'social'])

# %%
outlier_free_df = cleaner.removeOutliers(aggr_df, ['session_dur','youtube', 'netflix', 'google', 'gaming', 'email', 'social'])

# %%
sumar.plot_box(outlier_free_df, ['youtube', 'netflix'])
sumar.plot_box(outlier_free_df, ['google', 'email', 'social'])
sumar.plot_box(outlier_free_df, ['gaming'])

# %%
sumar.summ_columns(outlier_free_df)
# Out:
#             variables  missing_count  missing_percent_(%) data_type  \
# 0       MSISDN/Number              0                  0.0    object
# 1   xDr_session_count              0                  0.0     int64
# 2         session_dur              0                  0.0   float64
# 3            Total_DL              0                  0.0   float64
# 4            Total_UL              0                  0.0   float64
# 5           total_vol              0                  0.0   float64
# 6             youtube              0                  0.0   float64
# 7             netflix              0                  0.0   float64
# 8              google              0                  0.0   float64
# 9              gaming              0                  0.0   float64
# 10              email              0                  0.0   float64
# 11             social              0                  0.0   float64
# 12              other              0                  0.0   float64
#
#     unique_values
# 0           98804
# 1               7
# 2           70404
# 3           98801
# 4           98734
# 5           98801
# 6           98719
# 7           98716
# 8           98595
# 9           98802
# 10          98140
# 11          98120
# 12          98800

# %% [markdown]
# Basic summary of the aggregated dataframe.

# %%
outlier_free_df.describe()
# Out:
#        xDr_session_count    session_dur      Total_DL      Total_UL  \
# count       98804.000000   98804.000000  98804.000000  98804.000000
# mean            1.259575  114380.338640    572.971028     51.817685
# std             0.521917   70409.563804    361.403476     24.943180
# min             1.000000    7142.000000      8.827082      2.866892
# 25%             1.000000   63326.000000    298.043458     35.726345
# 50%             1.000000   95372.000000    543.630466     45.427653
# 75%             1.000000  161656.500000    771.843685     59.432680
# max             7.000000  324991.000000   3690.666979    332.044622
#
#           total_vol       youtube       netflix        google        gaming  \
# count  98804.000000  98804.000000  98804.000000  98804.000000  98804.000000
# mean     624.788713     28.503268     28.504271      9.831069    542.383127
# std      375.983697     15.690494     15.789492      5.663054    353.160100
# min       33.249009      0.078903      0.184569      0.040330      0.306358
# 25%      341.300094     18.065539     17.995513      5.717957    271.868433
# 50%      590.084076     25.787039     25.724300      9.187591    515.610819
# 75%      820.576448     35.520315     35.529224     12.470556    742.886427
# max     4009.943326    178.634466    190.646220     71.974850   3522.810324
#
#               email        social         other
# count  98804.000000  98804.000000  98804.000000
# mean       2.843202      2.304304    541.151300
# std        1.677751      1.502092    353.724684
# min        0.018176      0.001563      0.149045
# 25%        1.600313      1.147838    269.980394
# 50%        2.676761      2.189129    513.307202
# 75%        3.662333      3.162573    740.933181
# max       20.610254     15.720516   3379.939123

# %%
outlier_free_df[['youtube','gaming','email','netflix','social']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Comparing the two applications with the smallest data volume share

# %%
outlier_free_df[['email','social']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
outlier_free_df[['netflix','youtube']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.hist(outlier_free_df['session_dur'],bins=20, color='orange')
# Out:
# (array([ 6779.,  9110.,  5701.,  5002., 18083.,  8639.,  5694.,  5814.,
#          5455.,  5415.,  7838.,  3110.,  1823.,  1970.,  1714.,  2676.,
#          1472.,   877.,   792.,   840.]),
#  array([  7142.  ,  23034.45,  38926.9 ,  54819.35,  70711.8 ,  86604.25,
#         102496.7 , 118389.15, 134281.6 , 150174.05, 166066.5 , 181958.95,
#         197851.4 , 213743.85, 229636.3 , 245528.75, 261421.2 , 277313.65,
#         293206.1 , 309098.55, 324991.  ]),
#  <BarContainer object of 20 artists>)

# %%
sumar.showDistribution(outlier_free_df, ['youtube', 'netflix', 'google', 'gaming', 'email', 'social'], ['green','yellow','purple','red','orange','black'])

# %%
def bivariateAnalysis(df, cols, colors): 
    for i in range(len(cols)):
        plt.style.use('fivethirtyeight')
        plt.figure(figsize=(8, 4))
        sns.scatterplot(data = df, x=cols[i][0], y=cols[i][1], s=20, color=colors[i])

# %%
bivariateAnalysis(outlier_free_df, [['total_vol','gaming'],['total_vol','netflix'],['total_vol','youtube'],['total_vol','social'],['total_vol','email'],['total_vol','google']],['green','yellow','purple','red','orange','black'])

# %%
sumar.topDecile(outlier_free_df, ['Decile'],"session_dur", ['total_vol'], ['sum'], ['total_vol_p_decile'])
# Out:
#    Decile  total_vol_p_decile
# 0       0        5.004928e+06
# 1       1        5.538083e+06
# 2       2        6.159362e+06
# 3       3        6.409661e+06
# 4       4        3.886534e+06
# 5       5        5.856078e+06

# %%
test_list = ['youtube', 'netflix', 'google', 'gaming', 'email', 'social', 'other']
sumar.corrMatrix(outlier_free_df, test_list)
# Out:
#           youtube   netflix    google    gaming     email    social     other
# youtube  1.000000  0.567000  0.540704  0.473360  0.521501  0.476393  0.476963
# netflix  0.567000  1.000000  0.540756  0.472881  0.525195  0.479258  0.471908
# google   0.540704  0.540756  1.000000  0.455253  0.502460  0.457740  0.456342
# gaming   0.473360  0.472881  0.455253  1.000000  0.438724  0.402892  0.397899
# email    0.521501  0.525195  0.502460  0.438724  1.000000  0.447770  0.443133
# social   0.476393  0.479258  0.457740  0.402892  0.447770  1.000000  0.404354
# other    0.476963  0.471908  0.456342  0.397899  0.443133  0.404354  1.000000

# %%
#save_data_path = os.path.join(parent_dir,"data","teleco_aggr_data.csv") # setting path to data directory
#save_data_path_2 = os.path.join(parent_dir,"data","teleco_clean_data.csv") # setting path to data directory
#aggr_df.to_csv(save_data_path, index=False)
#df3.to_csv(save_data_path_2, index=False)
